# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('final.csv')
df
# Out:
#        latitude   longitude blk_no            road_name  postal_code  \
# 0      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 1      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 2      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 3      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 4      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# ...         ...         ...    ...                  ...          ...
# 40834  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40835  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40836  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40837  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40838  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
#
#                     address      cbd_dist  min_dist_mrt    month  \
# 0      174 ANG MO KIO AVE 4  10296.855747   1097.395548  2015-01
# ...

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code            float64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
#Check for null 
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %%
#Data PreProcessing 
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#        latitude   longitude blk_no            road_name  postal_code  \
# 0      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 1      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 2      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 3      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# 4      1.375097  103.837619    174  ANG MO KIO AVENUE 4     560174.0
# ...         ...         ...    ...                  ...          ...
# 40834  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40835  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40836  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40837  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
# 40838  1.300178  103.884043     14   KAMPONG ARANG ROAD     431014.0
#
#                     address      cbd_dist  min_dist_mrt    month  \
# 0      174 ANG MO KIO AVE 4  10296.855747   1097.395548  2015-01
# ...

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#            cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0      10296.855747   1097.395548            60.0                  62
# 1      10296.855747   1097.395548            60.0                  62
# 2      10296.855747   1097.395548            69.0                  62
# 3      10296.855747   1097.395548            45.0                  62
# 4      10296.855747   1097.395548            61.0                  62
# ...             ...           ...             ...                 ...
# 40834   4109.354096    662.611547           103.0                  60
# 40835   4109.354096    662.611547           135.0                  60
# 40836   4109.354096    662.611547           103.0                  60
# 40837   4109.354096    662.611547           103.0                  60
# 40838   4109.354096    662.611547           135.0                  60
#
#        storey_median  resale_price
# 0                8.0      255000.0
# 1               11.0      275000.0
# ...

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#            cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0      10296.855747   1097.395548            60.0                  62
# 1      10296.855747   1097.395548            60.0                  62
# 2      10296.855747   1097.395548            69.0                  62
# 3      10296.855747   1097.395548            45.0                  62
# 4      10296.855747   1097.395548            61.0                  62
# ...             ...           ...             ...                 ...
# 40834   4109.354096    662.611547           103.0                  60
# 40835   4109.354096    662.611547           135.0                  60
# 40836   4109.354096    662.611547           103.0                  60
# 40837   4109.354096    662.611547           103.0                  60
# 40838   4109.354096    662.611547           135.0                  60
#
#        storey_median  resale_price
# 0                8.0      255000.0
# 1               11.0      275000.0
# ...

# %%
list(scope_df)
# Out:
# ['cbd_dist',
#  'min_dist_mrt',
#  'floor_area_sqm',
#  'lease_remain_years',
#  'storey_median',
#  'resale_price']

# %%
list(df)
# Out:
# ['latitude',
#  'longitude',
#  'blk_no',
#  'road_name',
#  'postal_code',
#  'address',
#  'cbd_dist',
#  'min_dist_mrt',
#  'month',
#  'town',
#  'flat_type',
#  'block',
#  'street_name',
#  'storey_range',
#  'floor_area_sqm',
#  'flat_model',
#  'lease_commence_date',
#  'resale_price',
#  'remaining_lease',
#  'lease_remain_years',
#  'storey_median']

# %%
x = np.array(scope_df['floor_area_sqm']) # independent
y = np.array(scope_df['resale_price']) # dependent 
n = np.size(x)
print(n)
# Out:
# 39364

# %%
#initialize the parameters
a0 = 0                  #intercept
a1 = 0                  #Slop
lr = 0.0001             #Learning rate
iterations = 1000       # Number of iterations
error = []              # Error array to calculate cost for each iterations.
for itr in range(iterations):
    error_cost = 0
    cost_a0 = 0
    cost_a1 = 0
    for i in range(len(scope_df['floor_area_sqm'])):
        y_pred = a0+a1*scope_df['floor_area_sqm'][i]   # predict value for given x
        error_cost = error_cost +(scope_df['resale_price'][i]-y_pred)**2
        for j in range(len(scope_df['floor_area_sqm'])):
            partial_wrt_a0 = -2 * (scope_df['resale_price'][j] - (a0 + a1*scope_df['floor_area_sqm'][j]))   #partial derivative w.r.t a0
            partial_wrt_a1 = (-2*scope_df['floor_area_sqm'][j])*(scope_df['resale_price'][j]-(a0 + a1*scope_df['floor_area_sqm'][j]))   #partial derivative w.r.t a1
            cost_a0 = cost_a0 + partial_wrt_a0      #calculate cost for each number and add
            cost_a1 = cost_a1 + partial_wrt_a1      #calculate cost for each number and add
        a0 = a0 - lr * cost_a0    #update a0
        a1 = a1 - lr * cost_a1    #update a1
        print(itr,a0,a1)          #Check iteration and updated a0 and a1
    error.append(error_cost)      #Append the data in array

print(a0)
print(a1)
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,len(error)+1),error,color='red',linewidth = 5)
plt.title("Iteration vr error")
plt.xlabel("iterations")
plt.ylabel("Error")
pred = a0+a1*experience
print(pred)
plt.scatter(experience,salary,color = 'red')
plt.plot(experience,pred, color = 'green')
plt.xlabel("experience")
plt.ylabel("salary")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 25
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Check Skewness for the Linear Regression 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew
import statsmodels.api as sm
#warnings.filterwarnings('ignore')

# Generate some example data with skewness
np.random.seed(42)
x = np.random.exponential(size=1000)  # Exponential distribution (skewed)
y = 3 * x + 2 + np.random.normal(scale=10, size=1000)  # Linear relationship with noise

# Create a DataFrame
data = pd.DataFrame({'X': df['floor_area_sqm'], 'Y': df['resale_price']})
# Example assuming multiple independent variables
#data = sm.add_constant(data[['cbd_dist', 'min_dist_mrt', 'floor_area_sqm', 'storey_median']])

#['cbd_dist', 'min_dist_mrt', 'floor_area_sqm', 'lease_remain_years', 'storey_median',

# Check skewness of the dependent variable (Y)
print("Skewness of Y:", skew(data['Y']))

# Visualize the distribution of Y before transformation
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(data['Y'], bins=30, edgecolor='black')
plt.title("Distribution of Y (Before Transformation)")

# Log-transform Y to reduce skewness
data['Y_log'] = np.log1p(data['Y'])

# Check skewness of the log-transformed Y
print("Skewness of log(Y):", skew(data['Y_log']))

# Visualize the distribution of log(Y)
plt.subplot(1, 2, 2)
plt.hist(data['Y_log'], bins=30, edgecolor='black')
plt.title("Distribution of log(Y)")
plt.show()

plt.scatter(data['X'], data['Y_log'], color='red')  # Use 'data' instead of 'scope_df'
plt.plot(data['X'], model.predict(X), color='green')  # Assuming 'model' is your fitted OLS model

plt.xlabel("Floor sq") 
plt.ylabel("resale_price")

# Linear regression using statsmodels
X = sm.add_constant(data['X'])  # Add a constant term to the independent variable
model = sm.OLS(data['Y'], X).fit()

# Print the regression summary
print(model.summary())
# Out:
# Skewness of Y: 1.4039019216724575
# Skewness of log(Y): 0.46680366801155115
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 44
#      41 plt.show()
#      43 plt.scatter(data['X'], data['Y_log'], color='red')  # Use 'data' instead of 'scope_df'
# ---> 44 plt.plot(data['X'], model.predict(X), color='green')  # Assuming 'model' is your fitted OLS model
#      46 plt.xlabel("Floor sq")
#      47 plt.ylabel("resale_price")
#
# NameError: name 'model' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#               0         1         2         3         4
# 0     -0.300516  1.145206 -1.565791 -0.322859  0.231268
# 1     -0.300516  1.145206 -1.565791 -0.322859  0.675272
# 2     -0.300516  1.145206 -1.026496 -0.322859 -0.424035
# 3     -0.300516  1.145206 -2.675861 -0.322859  0.231268
# 4     -0.300516  1.145206 -1.502010 -0.322859 -0.424035
# ...         ...       ...       ...       ...       ...
# 39359 -1.648891  0.014017  0.519374 -0.503717 -1.701574
# 39360 -1.648891  0.014017  1.563320 -0.503717 -0.424035
# 39361 -1.648891  0.014017  0.519374 -0.503717  0.231268
# 39362 -1.648891  0.014017  0.519374 -0.503717  0.675272
# 39363 -1.648891  0.014017  1.563320 -0.503717  0.675272
#
# [39364 rows x 5 columns]

# %%
# Data for training and testing purpose

from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 9, 'min_samples_split': 5}
#
# Mean squared error: 0.015595613986388373
# Mean Absolute Error 0.09916205956169898
# Root Mean squared error: 0.12488240062710347
#
# R-squared: 0.8607375793008918

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 227446.8514335741

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
